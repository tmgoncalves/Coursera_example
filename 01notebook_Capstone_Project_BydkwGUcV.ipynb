# %% [markdown]
# # Code For Capstone Project
#
#
# ### Import necessary Libraries

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.19.0-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  22.65 MB/s
# geopy-1.19.0-p 100% |################################| Time: 0:00:00  31.74 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  44.04 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  32.34 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  35.14 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  39.99 MB/s
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'MRATCEYMUU1JHCBMN4G3OTYULZPLS2N24Z424OEJNJY0J1OL' # your Foursquare ID
CLIENT_SECRET = 'TUJDNG0SQZ4PRGSRIUN4CPNPFGIDZB2VUVRALRKJIXTJ2Y0F' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: MRATCEYMUU1JHCBMN4G3OTYULZPLS2N24Z424OEJNJY0J1OL
# CLIENT_SECRET:TUJDNG0SQZ4PRGSRIUN4CPNPFGIDZB2VUVRALRKJIXTJ2Y0F

# %% [markdown]
# ### Finding the number of restaurants near two famous tourist destinations & visualise them. Selecting best out of two and making recommendation to open a restaurant to the client near that location.
#
# ### 1. Taj Mahal
#
# Latitude and longitude coordinates

# %%
    address = 'Taj Mahal'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.19.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# 27.175002 78.0421170902921

# %% [markdown]
# Define a query to search for restaurants that is within 1 km from the Taj Mahal

# %%
search_query = 'Restaurant'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %% [markdown]
# Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MRATCEYMUU1JHCBMN4G3OTYULZPLS2N24Z424OEJNJY0J1OL&client_secret=TUJDNG0SQZ4PRGSRIUN4CPNPFGIDZB2VUVRALRKJIXTJ2Y0F&ll=27.175002,78.0421170902921&v=20180604&query=Restaurant&radius=1000&limit=30'

# %% [markdown]
# Using GET Request to examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cb898729fb6b7770b79b6b5'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4d172bb81356a093322fda82',
#     'location': {'address': 'Fatehabad Road',
#      'cc': 'IN',
#      'country': 'India',
#      'crossStreet': 'Near Kailash Cinema',
#      'distance': 1284,
#      'formattedAddress': ['Fatehabad Road (Near Kailash Cinema)', 'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.164503607098183,
#        'lng': 78.03674221704243}],
#      'lat': 27.164503607098183,
#      'lng': 78.03674221704243,
#      'neighborhood': 'Taj Ganj'},
#     'name': 'Quality Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4d622b6fef378cfa1cd693a6',
#     'location': {'cc': 'IN',
#      'country': 'India',
#      'distance': 224,
#      'formattedAddress': ['India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.173025798046947,
#        'lng': 78.04168564815829}],
#      'lat': 27.173025798046947,
#      'lng': 78.04168564815829},
#     'name': 'Nero Quality Multicuisine Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/bedandbreakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f8931735',
#       'name': 'Bed & Breakfast',
#       'pluralName': 'Bed & Breakfasts',
#       'primary': True,
#       'shortName': 'B & B'}],
#     'hasPerk': False,
#     'id': '4dbae4c4107ff2aa48b44f0d',
#     'location': {'address': '18/184 Purani Mandi Circle, Fatehabad Road',
#      'cc': 'IN',
#      'city': 'Āgra',
#      'country': 'India',
#      'distance': 1084,
#      'formattedAddress': ['18/184 Purani Mandi Circle, Fatehabad Road',
#       'Āgra',
#       'Uttar Pradesh',
#       'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.166284911269702,
#        'lng': 78.03723644454263}],
#      'lat': 27.166284911269702,
#      'lng': 78.03723644454263,
#      'state': 'Uttar Pradesh'},
#     'name': 'Maya Hotel and Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4f7293fae4b043e3bbbba757',
#     'location': {'address': 'South Gate',
#      'cc': 'IN',
#      'city': 'Āgra',
#      'country': 'India',
#      'crossStreet': 'Tajganj',
#      'distance': 685,
#      'formattedAddress': ['South Gate (Tajganj)',
#       'Āgra',
#       'Uttar Pradesh',
#       'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.168923730082508,
#        'lng': 78.04324609765891}],
#      'lat': 27.168923730082508,
#      'lng': 78.04324609765891,
#      'state': 'Uttar Pradesh'},
#     'name': 'Yash Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4f75de38e4b0ca03a367b1c0',
#     'location': {'cc': 'IN',
#      'country': 'India',
#      'distance': 648,
#      'formattedAddress': ['India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.169184311563004,
#        'lng': 78.04250488698014}],
#      'lat': 27.169184311563004,
#      'lng': 78.04250488698014},
#     'name': 'Join us Roof Top Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5a8c032d286fda4b971441ce',
#     'location': {'cc': 'IN',
#      'city': 'Āgra',
#      'country': 'India',
#      'distance': 595,
#      'formattedAddress': ['Āgra 282001', 'Uttar Pradesh', 'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.169825,
#        'lng': 78.040589}],
#      'lat': 27.169825,
#      'lng': 78.040589,
#      'postalCode': '282001',
#      'state': 'Uttar Pradesh'},
#     'name': 'Rajesh Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '54135bf5e4b08f3d2429dfe0',
#       'name': 'Multicuisine Indian Restaurant',
#       'pluralName': 'Multicuisine Indian Restaurants',
#       'primary': True,
#       'shortName': 'Multicuisine Indian'}],
#     'hasPerk': False,
#     'id': '56542b54498e727d759bbdd1',
#     'location': {'cc': 'IN',
#      'country': 'India',
#      'distance': 541,
#      'formattedAddress': ['India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.170587,
#        'lng': 78.039833}],
#      'lat': 27.170587,
#      'lng': 78.039833},
#     'name': 'Taj Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5c2c5469340a58002c116c63',
#     'location': {'cc': 'IN',
#      'city': 'Āgra',
#      'country': 'India',
#      'distance': 558,
#      'formattedAddress': ['Āgra 282001', 'Uttar Pradesh', 'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.170219,
#        'lng': 78.043803}],
#      'lat': 27.170219,
#      'lng': 78.043803,
#      'postalCode': '282001',
#      'state': 'Uttar Pradesh'},
#     'name': 'Shiva Family Restaurant & Guest House',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4f76bdb5e4b015efa48ae9dc',
#     'location': {'cc': 'IN',
#      'country': 'India',
#      'distance': 597,
#      'formattedAddress': ['India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.169634155636825,
#        'lng': 78.04209805487884}],
#      'lat': 27.169634155636825,
#      'lng': 78.04209805487884},
#     'name': 'Treat Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'primary': True,
#       'shortName': 'Hotel'}],
#     'hasPerk': False,
#     'id': '507bbd7fe4b0109f36b90d3a',
#     'location': {'cc': 'IN',
#      'country': 'India',
#      'distance': 657,
#      'formattedAddress': ['India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.16910596777691,
#        'lng': 78.04178596345265}],
#      'lat': 27.16910596777691,
#      'lng': 78.04178596345265},
#     'name': 'Shahjahan Hotels & Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4f124d07e4b067f67094157c',
#     'location': {'cc': 'IN',
#      'city': 'Āgra',
#      'country': 'India',
#      'distance': 650,
#      'formattedAddress': ['Āgra', 'Uttar Pradesh', 'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.169166990992057,
#        'lng': 78.04242386260445}],
#      'lat': 27.169166990992057,
#      'lng': 78.04242386260445,
#      'state': 'Uttar Pradesh'},
#     'name': 'Shankara Vegis Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'primary': True,
#       'shortName': 'Asian'}],
#     'hasPerk': False,
#     'id': '4ec71cd6d3e3e131f1d81074',
#     'location': {'cc': 'IN',
#      'country': 'India',
#      'distance': 654,
#      'formattedAddress': ['Uttar Pradesh', 'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.169133115897328,
#        'lng': 78.04244358361169}],
#      'lat': 27.169133115897328,
#      'lng': 78.04244358361169,
#      'state': 'Uttar Pradesh'},
#     'name': 'Zee Cafe Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4f01cc3e5c5c51dd30277cc3',
#     'location': {'cc': 'IN',
#      'country': 'India',
#      'distance': 664,
#      'formattedAddress': ['India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.169034446500383,
#        'lng': 78.04188070558884}],
#      'lat': 27.169034446500383,
#      'lng': 78.04188070558884},
#     'name': 'Gulshan Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '52dd366e11d282e863ad9bbf',
#     'location': {'cc': 'IN',
#      'country': 'India',
#      'distance': 840,
#      'formattedAddress': ['India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.16758668858207,
#        'lng': 78.04050414984657}],
#      'lat': 27.16758668858207,
#      'lng': 78.04050414984657},
#     'name': 'Akhtar Restaurant',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/boat_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d12d951735',
#       'name': 'Boat or Ferry',
#       'pluralName': 'Boats or Ferries',
#       'primary': True,
#       'shortName': 'Boat / Ferry'}],
#     'hasPerk': False,
#     'id': '4de2d69218385df2b02e4855',
#     'location': {'address': 'Pathyabad Road',
#      'cc': 'IN',
#      'city': 'Āgra',
#      'country': 'India',
#      'distance': 204,
#      'formattedAddress': ['Pathyabad Road', 'Āgra', 'Uttar Pradesh', 'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.173163679524194,
#        'lng': 78.04214263929408}],
#      'lat': 27.173163679524194,
#      'lng': 78.04214263929408,
#      'state': 'Uttar Pradesh'},
#     'name': 'Green Park',
#     'referralId': 'v-1555601522'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'id': '50aa9e094b90af0d42d5de0d',
#       'name': 'City',
#       'pluralName': 'Cities',
#       'primary': True,
#       'shortName': 'City'}],
#     'hasPerk': False,
#     'id': '4e0346e2152032d52cfb1b60',
#     'location': {'cc': 'IN',
#      'country': 'India',
#      'distance': 1022,
#      'formattedAddress': ['282001', 'Uttar Pradesh', 'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.167860482093214,
#        'lng': 78.03562197154069}],
#      'lat': 27.167860482093214,
#      'lng': 78.03562197154069,
#      'postalCode': '282001',
#      'state': 'Uttar Pradesh'},
#     'name': 'Agra | आगरा |آگره (Agra)',
#     'referralId': 'v-1555601522'}]}}

# %% [markdown]
# Get relevant part of JSON and transform it into a pandas dataframe

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'primary': True, 'pluralName': 'Indian Resta...    False
# 1  [{'primary': True, 'pluralName': 'Indian Resta...    False
# 2  [{'primary': True, 'pluralName': 'Bed & Breakf...    False
# 3  [{'primary': True, 'pluralName': 'Indian Resta...    False
# 4  [{'primary': True, 'pluralName': 'Indian Resta...    False
#
#                          id                            location.address  \
# 0  4d172bb81356a093322fda82                              Fatehabad Road
# 1  4d622b6fef378cfa1cd693a6                                         NaN
# 2  4dbae4c4107ff2aa48b44f0d  18/184 Purani Mandi Circle, Fatehabad Road
# 3  4f7293fae4b043e3bbbba757                                  South Gate
# 4  4f75de38e4b0ca03a367b1c0                                         NaN
#
#   location.cc location.city location.country location.crossStreet  \
# 0          IN           NaN            India  Near Kailash Cinema
# 1          IN           NaN            India                  NaN
# 2          IN          Āgra            India                  NaN
# 3          IN          Āgra            India              Tajganj
# 4          IN           NaN            India                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0               1284      [Fatehabad Road (Near Kailash Cinema), India]
# 1                224                                            [India]
# 2               1084  [18/184 Purani Mandi Circle, Fatehabad Road, Ā...
# 3                685  [South Gate (Tajganj), Āgra, Uttar Pradesh, In...
# 4                648                                            [India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lat': 27.164503607098183, 'lng': 78.0367422...     27.164504
# 1  [{'lat': 27.173025798046947, 'lng': 78.0416856...     27.173026
# 2  [{'lat': 27.166284911269702, 'lng': 78.0372364...     27.166285
# 3  [{'lat': 27.168923730082508, 'lng': 78.0432460...     27.168924
# 4  [{'lat': 27.169184311563004, 'lng': 78.0425048...     27.169184
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0     78.036742              Taj Ganj                 NaN            NaN
# 1     78.041686                   NaN                 NaN            NaN
# 2     78.037236                   NaN                 NaN  Uttar Pradesh
# 3     78.043246                   NaN                 NaN  Uttar Pradesh
# 4     78.042505                   NaN                 NaN            NaN
#
#                                    name    referralId
# 0                    Quality Restaurant  v-1555601522
# 1  Nero Quality Multicuisine Restaurant  v-1555601522
# 2             Maya Hotel and Restaurant  v-1555601522
# 3                       Yash Restaurant  v-1555601522
# 4           Join us Roof Top Restaurant  v-1555601522

# %% [markdown]
# ### Filter dataframe

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered
# Out:
#                                      name                      categories  \
# 0                      Quality Restaurant               Indian Restaurant
# 1    Nero Quality Multicuisine Restaurant               Indian Restaurant
# 2               Maya Hotel and Restaurant                 Bed & Breakfast
# 3                         Yash Restaurant               Indian Restaurant
# 4             Join us Roof Top Restaurant               Indian Restaurant
# 5                       Rajesh Restaurant               Indian Restaurant
# 6                          Taj Restaurant  Multicuisine Indian Restaurant
# 7   Shiva Family Restaurant & Guest House               Indian Restaurant
# 8                        Treat Restaurant               Indian Restaurant
# 9           Shahjahan Hotels & Restaurant                           Hotel
# 10              Shankara Vegis Restaurant               Indian Restaurant
# 11                    Zee Cafe Restaurant                Asian Restaurant
# 12                     Gulshan Restaurant               Indian Restaurant
# 13                      Akhtar Restaurant               Indian Restaurant
# 14                             Green Park                   Boat or Ferry
# 15               Agra | आगरा |آگره (Agra)                            City
#
#                                        address  cc  city country  \
# 0                               Fatehabad Road  IN   NaN   India
# 1                                          NaN  IN   NaN   India
# 2   18/184 Purani Mandi Circle, Fatehabad Road  IN  Āgra   India
# 3                                   South Gate  IN  Āgra   India
# 4                                          NaN  IN   NaN   India
# 5                                          NaN  IN  Āgra   India
# 6                                          NaN  IN   NaN   India
# 7                                          NaN  IN  Āgra   India
# 8                                          NaN  IN   NaN   India
# 9                                          NaN  IN   NaN   India
# 10                                         NaN  IN  Āgra   India
# 11                                         NaN  IN   NaN   India
# 12                                         NaN  IN   NaN   India
# 13                                         NaN  IN   NaN   India
# 14                              Pathyabad Road  IN  Āgra   India
# 15                                         NaN  IN   NaN   India
#
#             crossStreet  distance  \
# 0   Near Kailash Cinema      1284
# 1                   NaN       224
# 2                   NaN      1084
# 3               Tajganj       685
# 4                   NaN       648
# 5                   NaN       595
# 6                   NaN       541
# 7                   NaN       558
# 8                   NaN       597
# 9                   NaN       657
# 10                  NaN       650
# 11                  NaN       654
# 12                  NaN       664
# 13                  NaN       840
# 14                  NaN       204
# 15                  NaN      1022
#
#                                      formattedAddress  \
# 0       [Fatehabad Road (Near Kailash Cinema), India]
# 1                                             [India]
# 2   [18/184 Purani Mandi Circle, Fatehabad Road, Ā...
# 3   [South Gate (Tajganj), Āgra, Uttar Pradesh, In...
# 4                                             [India]
# 5                 [Āgra 282001, Uttar Pradesh, India]
# 6                                             [India]
# 7                 [Āgra 282001, Uttar Pradesh, India]
# 8                                             [India]
# 9                                             [India]
# 10                       [Āgra, Uttar Pradesh, India]
# 11                             [Uttar Pradesh, India]
# 12                                            [India]
# 13                                            [India]
# 14       [Pathyabad Road, Āgra, Uttar Pradesh, India]
# 15                     [282001, Uttar Pradesh, India]
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lat': 27.164503607098183, 'lng': 78.0367422...  27.164504  78.036742
# 1   [{'lat': 27.173025798046947, 'lng': 78.0416856...  27.173026  78.041686
# 2   [{'lat': 27.166284911269702, 'lng': 78.0372364...  27.166285  78.037236
# 3   [{'lat': 27.168923730082508, 'lng': 78.0432460...  27.168924  78.043246
# 4   [{'lat': 27.169184311563004, 'lng': 78.0425048...  27.169184  78.042505
# 5   [{'lat': 27.169825, 'lng': 78.040589, 'label':...  27.169825  78.040589
# 6   [{'lat': 27.170587, 'lng': 78.039833, 'label':...  27.170587  78.039833
# 7   [{'lat': 27.170219, 'lng': 78.043803, 'label':...  27.170219  78.043803
# 8   [{'lat': 27.169634155636825, 'lng': 78.0420980...  27.169634  78.042098
# 9   [{'lat': 27.16910596777691, 'lng': 78.04178596...  27.169106  78.041786
# 10  [{'lat': 27.169166990992057, 'lng': 78.0424238...  27.169167  78.042424
# 11  [{'lat': 27.169133115897328, 'lng': 78.0424435...  27.169133  78.042444
# 12  [{'lat': 27.169034446500383, 'lng': 78.0418807...  27.169034  78.041881
# 13  [{'lat': 27.16758668858207, 'lng': 78.04050414...  27.167587  78.040504
# 14  [{'lat': 27.173163679524194, 'lng': 78.0421426...  27.173164  78.042143
# 15  [{'lat': 27.167860482093214, 'lng': 78.0356219...  27.167860  78.035622
#
#    neighborhood postalCode          state                        id
# 0      Taj Ganj        NaN            NaN  4d172bb81356a093322fda82
# 1           NaN        NaN            NaN  4d622b6fef378cfa1cd693a6
# 2           NaN        NaN  Uttar Pradesh  4dbae4c4107ff2aa48b44f0d
# 3           NaN        NaN  Uttar Pradesh  4f7293fae4b043e3bbbba757
# 4           NaN        NaN            NaN  4f75de38e4b0ca03a367b1c0
# 5           NaN     282001  Uttar Pradesh  5a8c032d286fda4b971441ce
# 6           NaN        NaN            NaN  56542b54498e727d759bbdd1
# 7           NaN     282001  Uttar Pradesh  5c2c5469340a58002c116c63
# 8           NaN        NaN            NaN  4f76bdb5e4b015efa48ae9dc
# 9           NaN        NaN            NaN  507bbd7fe4b0109f36b90d3a
# 10          NaN        NaN  Uttar Pradesh  4f124d07e4b067f67094157c
# 11          NaN        NaN  Uttar Pradesh  4ec71cd6d3e3e131f1d81074
# 12          NaN        NaN            NaN  4f01cc3e5c5c51dd30277cc3
# 13          NaN        NaN            NaN  52dd366e11d282e863ad9bbf
# 14          NaN        NaN  Uttar Pradesh  4de2d69218385df2b02e4855
# 15          NaN     282001  Uttar Pradesh  4e0346e2152032d52cfb1b60

# %%
dataframe_filtered=dataframe_filtered.head(13) # Removing last two rows as they are not restaurants.
dataframe_filtered
# Out:
#                                      name                      categories  \
# 0                      Quality Restaurant               Indian Restaurant
# 1    Nero Quality Multicuisine Restaurant               Indian Restaurant
# 2               Maya Hotel and Restaurant                 Bed & Breakfast
# 3                         Yash Restaurant               Indian Restaurant
# 4             Join us Roof Top Restaurant               Indian Restaurant
# 5                       Rajesh Restaurant               Indian Restaurant
# 6                          Taj Restaurant  Multicuisine Indian Restaurant
# 7   Shiva Family Restaurant & Guest House               Indian Restaurant
# 8                        Treat Restaurant               Indian Restaurant
# 9           Shahjahan Hotels & Restaurant                           Hotel
# 10              Shankara Vegis Restaurant               Indian Restaurant
# 11                    Zee Cafe Restaurant                Asian Restaurant
# 12                     Gulshan Restaurant               Indian Restaurant
#
#                                        address  cc  city country  \
# 0                               Fatehabad Road  IN   NaN   India
# 1                                          NaN  IN   NaN   India
# 2   18/184 Purani Mandi Circle, Fatehabad Road  IN  Āgra   India
# 3                                   South Gate  IN  Āgra   India
# 4                                          NaN  IN   NaN   India
# 5                                          NaN  IN  Āgra   India
# 6                                          NaN  IN   NaN   India
# 7                                          NaN  IN  Āgra   India
# 8                                          NaN  IN   NaN   India
# 9                                          NaN  IN   NaN   India
# 10                                         NaN  IN  Āgra   India
# 11                                         NaN  IN   NaN   India
# 12                                         NaN  IN   NaN   India
#
#             crossStreet  distance  \
# 0   Near Kailash Cinema      1284
# 1                   NaN       224
# 2                   NaN      1084
# 3               Tajganj       685
# 4                   NaN       648
# 5                   NaN       595
# 6                   NaN       541
# 7                   NaN       558
# 8                   NaN       597
# 9                   NaN       657
# 10                  NaN       650
# 11                  NaN       654
# 12                  NaN       664
#
#                                      formattedAddress  \
# 0       [Fatehabad Road (Near Kailash Cinema), India]
# 1                                             [India]
# 2   [18/184 Purani Mandi Circle, Fatehabad Road, Ā...
# 3   [South Gate (Tajganj), Āgra, Uttar Pradesh, In...
# 4                                             [India]
# 5                 [Āgra 282001, Uttar Pradesh, India]
# 6                                             [India]
# 7                 [Āgra 282001, Uttar Pradesh, India]
# 8                                             [India]
# 9                                             [India]
# 10                       [Āgra, Uttar Pradesh, India]
# 11                             [Uttar Pradesh, India]
# 12                                            [India]
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lat': 27.164503607098183, 'lng': 78.0367422...  27.164504  78.036742
# 1   [{'lat': 27.173025798046947, 'lng': 78.0416856...  27.173026  78.041686
# 2   [{'lat': 27.166284911269702, 'lng': 78.0372364...  27.166285  78.037236
# 3   [{'lat': 27.168923730082508, 'lng': 78.0432460...  27.168924  78.043246
# 4   [{'lat': 27.169184311563004, 'lng': 78.0425048...  27.169184  78.042505
# 5   [{'lat': 27.169825, 'lng': 78.040589, 'label':...  27.169825  78.040589
# 6   [{'lat': 27.170587, 'lng': 78.039833, 'label':...  27.170587  78.039833
# 7   [{'lat': 27.170219, 'lng': 78.043803, 'label':...  27.170219  78.043803
# 8   [{'lat': 27.169634155636825, 'lng': 78.0420980...  27.169634  78.042098
# 9   [{'lat': 27.16910596777691, 'lng': 78.04178596...  27.169106  78.041786
# 10  [{'lat': 27.169166990992057, 'lng': 78.0424238...  27.169167  78.042424
# 11  [{'lat': 27.169133115897328, 'lng': 78.0424435...  27.169133  78.042444
# 12  [{'lat': 27.169034446500383, 'lng': 78.0418807...  27.169034  78.041881
#
#    neighborhood postalCode          state                        id
# 0      Taj Ganj        NaN            NaN  4d172bb81356a093322fda82
# 1           NaN        NaN            NaN  4d622b6fef378cfa1cd693a6
# 2           NaN        NaN  Uttar Pradesh  4dbae4c4107ff2aa48b44f0d
# 3           NaN        NaN  Uttar Pradesh  4f7293fae4b043e3bbbba757
# 4           NaN        NaN            NaN  4f75de38e4b0ca03a367b1c0
# 5           NaN     282001  Uttar Pradesh  5a8c032d286fda4b971441ce
# 6           NaN        NaN            NaN  56542b54498e727d759bbdd1
# 7           NaN     282001  Uttar Pradesh  5c2c5469340a58002c116c63
# 8           NaN        NaN            NaN  4f76bdb5e4b015efa48ae9dc
# 9           NaN        NaN            NaN  507bbd7fe4b0109f36b90d3a
# 10          NaN        NaN  Uttar Pradesh  4f124d07e4b067f67094157c
# 11          NaN        NaN  Uttar Pradesh  4ec71cd6d3e3e131f1d81074
# 12          NaN        NaN            NaN  4f01cc3e5c5c51dd30277cc3

# %% [markdown]
# ### Calculating number of restaurants near Taj Mahal in 1 Km radius

# %%
a=dataframe_filtered['name'].count()
print('There are {} restaurants near Taj Mahal in 1 Km radius.'.format(a))
# Out:
# There are 13 restaurants near Taj Mahal in 1 Km radius.

# %% [markdown]
# ### Visualizing restaurants that are nearby Taj Mahal

# %%
dataframe_filtered.name
# Out:
# 0                        Quality Restaurant
# 1      Nero Quality Multicuisine Restaurant
# 2                 Maya Hotel and Restaurant
# 3                           Yash Restaurant
# 4               Join us Roof Top Restaurant
# 5                         Rajesh Restaurant
# 6                            Taj Restaurant
# 7     Shiva Family Restaurant & Guest House
# 8                          Treat Restaurant
# 9             Shahjahan Hotels & Restaurant
# 10                Shankara Vegis Restaurant
# 11                      Zee Cafe Restaurant
# 12                       Gulshan Restaurant
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)
# add a red circle marker to represent the Taj Mahal
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Taj Mahal',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2. India Gate
#
# - Latitude and longitude coordinates

# %%
add = 'India Gate'

geolocator = Nominatim()
location = geolocator.geocode(add)
latitudeig = location.latitude
longitudeig = location.longitude
print(latitudeig, longitudeig)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.19.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# 28.6128924 77.2294312

# %% [markdown]
# ### Define a query to search for restaurants that is within 1 km from the India Gate

# %%
search_query = 'Restaurant'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %% [markdown]
# ### Define the corresponding URL

# %%
url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitudeig, longitudeig, VERSION, search_query, radius, LIMIT)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MRATCEYMUU1JHCBMN4G3OTYULZPLS2N24Z424OEJNJY0J1OL&client_secret=TUJDNG0SQZ4PRGSRIUN4CPNPFGIDZB2VUVRALRKJIXTJ2Y0F&ll=28.6128924,77.2294312&v=20180604&query=Restaurant&radius=1000&limit=30'

# %% [markdown]
# ### Using GET Request to examine the results

# %%
resultsig = requests.get(url2).json()
resultsig
# Out:
# {'meta': {'code': 200, 'requestId': '5cb89963f594df78c480183e'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4c30890aac0ab71332021c1e',
#     'location': {'address': 'Pandara Road',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'country': 'India',
#      'distance': 546,
#      'formattedAddress': ['Pandara Road', 'New Delhi India', 'Delhi', 'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.608010137218567,
#        'lng': 77.22998865890446}],
#      'lat': 28.608010137218567,
#      'lng': 77.22998865890446,
#      'postalCode': 'India',
#      'state': 'Delhi'},
#     'name': 'Gulati Restaurant',
#     'referralId': 'v-1555601763'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4ba5f037f964a520452a39e3',
#     'location': {'address': '16 Pandara Road Market',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'country': 'India',
#      'distance': 544,
#      'formattedAddress': ['16 Pandara Road Market',
#       'New Delhi',
#       'Delhi',
#       'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.608018528891723,
#        'lng': 77.2298963114413}],
#      'lat': 28.608018528891723,
#      'lng': 77.2298963114413,
#      'state': 'Delhi'},
#     'name': 'Pindi Restaurant',
#     'referralId': 'v-1555601763'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'primary': True,
#       'shortName': 'Vegetarian / Vegan'}],
#     'hasPerk': False,
#     'id': '5227376f8bbde993b98f0d21',
#     'location': {'address': '8, Pandara Road Market',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'country': 'India',
#      'distance': 442,
#      'formattedAddress': ['8, Pandara Road Market',
#       'New Delhi 110003',
#       'Delhi',
#       'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.609089135775704,
#        'lng': 77.23074316978455}],
#      'lat': 28.609089135775704,
#      'lng': 77.23074316978455,
#      'postalCode': '110003',
#      'state': 'Delhi'},
#     'name': 'Veg Gulati Restaurant',
#     'referralId': 'v-1555601763'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '55dac38a498eac73066a0bda',
#     'location': {'address': 'Dr. Zakir Hussain Marg, New Delhi',
#      'cc': 'IN',
#      'city': 'Delhi',
#      'country': 'India',
#      'distance': 1046,
#      'formattedAddress': ['Dr. Zakir Hussain Marg, New Delhi',
#       'Delhi 110003',
#       'Delhi',
#       'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.605349757759758,
#        'lng': 77.23582863807678}],
#      'lat': 28.605349757759758,
#      'lng': 77.23582863807678,
#      'postalCode': '110003',
#      'state': 'Delhi'},
#     'name': 'The Oberoi - Taipan Chinese Restaurant',
#     'referralId': 'v-1555601763'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4c65834faebea5939e8870d0',
#     'location': {'address': 'Taj Mahal Hotel,  Lower Lobby Level',
#      'cc': 'IN',
#      'city': 'New Delhi',
#      'country': 'India',
#      'crossStreet': '1 Mansingh Road',
#      'distance': 1080,
#      'formattedAddress': ['Taj Mahal Hotel,  Lower Lobby Level (1 Mansingh Road)',
#       'New Delhi',
#       'Delhi',
#       'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 28.60454694756125,
#        'lng': 77.2237810008916}],
#      'lat': 28.60454694756125,
#      'lng': 77.2237810008916,
#      'state': 'Delhi'},
#     'name': 'Varq | वर्क',
#     'referralId': 'v-1555601763'}]}}

# %% [markdown]
# ### Get relevant part of JSON and transform it into a pandas dataframe

# %%
venuesig = resultsig['response']['venues']

df = json_normalize(venuesig)
df.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'primary': True, 'pluralName': 'Indian Resta...    False
# 1  [{'primary': True, 'pluralName': 'Restaurants'...    False
# 2  [{'primary': True, 'pluralName': 'Vegetarian /...    False
# 3  [{'primary': True, 'pluralName': 'Chinese Rest...    False
# 4  [{'primary': True, 'pluralName': 'Indian Resta...    False
#
#                          id                     location.address location.cc  \
# 0  4c30890aac0ab71332021c1e                         Pandara Road          IN
# 1  4ba5f037f964a520452a39e3               16 Pandara Road Market          IN
# 2  5227376f8bbde993b98f0d21               8, Pandara Road Market          IN
# 3  55dac38a498eac73066a0bda    Dr. Zakir Hussain Marg, New Delhi          IN
# 4  4c65834faebea5939e8870d0  Taj Mahal Hotel,  Lower Lobby Level          IN
#
#   location.city location.country location.crossStreet  location.distance  \
# 0     New Delhi            India                  NaN                546
# 1     New Delhi            India                  NaN                544
# 2     New Delhi            India                  NaN                442
# 3         Delhi            India                  NaN               1046
# 4     New Delhi            India      1 Mansingh Road               1080
#
#                            location.formattedAddress  \
# 0      [Pandara Road, New Delhi India, Delhi, India]
# 1  [16 Pandara Road Market, New Delhi, Delhi, India]
# 2  [8, Pandara Road Market, New Delhi 110003, Del...
# 3  [Dr. Zakir Hussain Marg, New Delhi, Delhi 1100...
# 4  [Taj Mahal Hotel,  Lower Lobby Level (1 Mansin...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lat': 28.608010137218567, 'lng': 77.2299886...     28.608010
# 1  [{'lat': 28.608018528891723, 'lng': 77.2298963...     28.608019
# 2  [{'lat': 28.609089135775704, 'lng': 77.2307431...     28.609089
# 3  [{'lat': 28.605349757759758, 'lng': 77.2358286...     28.605350
# 4  [{'lat': 28.60454694756125, 'lng': 77.22378100...     28.604547
#
#    location.lng location.postalCode location.state  \
# 0     77.229989               India          Delhi
# 1     77.229896                 NaN          Delhi
# 2     77.230743              110003          Delhi
# 3     77.235829              110003          Delhi
# 4     77.223781                 NaN          Delhi
#
#                                      name    referralId
# 0                       Gulati Restaurant  v-1555601763
# 1                        Pindi Restaurant  v-1555601763
# 2                   Veg Gulati Restaurant  v-1555601763
# 3  The Oberoi - Taipan Chinese Restaurant  v-1555601763
# 4                             Varq | वर्क  v-1555601763

# %% [markdown]
# ### Filter dataframe

# %%
filteredcolumns = ['name', 'categories'] + [col for col in df.columns if col.startswith('location.')] + ['id']
dataframefiltered = df.loc[:, filteredcolumns]

dataframefiltered['categories'] = dataframefiltered.apply(get_category_type, axis=1)
dataframefiltered.columns = [column.split('.')[-1] for column in dataframefiltered.columns]
dataframefiltered
# Out:
#                                      name                     categories  \
# 0                       Gulati Restaurant              Indian Restaurant
# 1                        Pindi Restaurant                     Restaurant
# 2                   Veg Gulati Restaurant  Vegetarian / Vegan Restaurant
# 3  The Oberoi - Taipan Chinese Restaurant             Chinese Restaurant
# 4                             Varq | वर्क              Indian Restaurant
#
#                                address  cc       city country  \
# 0                         Pandara Road  IN  New Delhi   India
# 1               16 Pandara Road Market  IN  New Delhi   India
# 2               8, Pandara Road Market  IN  New Delhi   India
# 3    Dr. Zakir Hussain Marg, New Delhi  IN      Delhi   India
# 4  Taj Mahal Hotel,  Lower Lobby Level  IN  New Delhi   India
#
#        crossStreet  distance  \
# 0              NaN       546
# 1              NaN       544
# 2              NaN       442
# 3              NaN      1046
# 4  1 Mansingh Road      1080
#
#                                     formattedAddress  \
# 0      [Pandara Road, New Delhi India, Delhi, India]
# 1  [16 Pandara Road Market, New Delhi, Delhi, India]
# 2  [8, Pandara Road Market, New Delhi 110003, Del...
# 3  [Dr. Zakir Hussain Marg, New Delhi, Delhi 1100...
# 4  [Taj Mahal Hotel,  Lower Lobby Level (1 Mansin...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'lat': 28.608010137218567, 'lng': 77.2299886...  28.608010  77.229989
# 1  [{'lat': 28.608018528891723, 'lng': 77.2298963...  28.608019  77.229896
# 2  [{'lat': 28.609089135775704, 'lng': 77.2307431...  28.609089  77.230743
# 3  [{'lat': 28.605349757759758, 'lng': 77.2358286...  28.605350  77.235829
# 4  [{'lat': 28.60454694756125, 'lng': 77.22378100...  28.604547  77.223781
#
#   postalCode  state                        id
# 0      India  Delhi  4c30890aac0ab71332021c1e
# 1        NaN  Delhi  4ba5f037f964a520452a39e3
# 2     110003  Delhi  5227376f8bbde993b98f0d21
# 3     110003  Delhi  55dac38a498eac73066a0bda
# 4        NaN  Delhi  4c65834faebea5939e8870d0

# %% [markdown]
# ### Calculating number of restaurants near India Gate in 1 Km radius

# %%
b=dataframefiltered['name'].count()
print('There are {} restaurants near India Gate in 1 Km radius.'.format(b))
# Out:
# There are 5 restaurants near India Gate in 1 Km radius.

# %% [markdown]
# ### Visualizing restaurants that are nearby India Gate
#
# ### dataframefiltered.name

# %%
venuesmap = folium.Map(location=[latitudeig, longitudeig], zoom_start=13)
# add a red circle marker to represent the India Gate
folium.features.CircleMarker(
    [latitudeig, longitudeig],
    radius=10,
    color='red',
    popup='India Gate',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venuesmap)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframefiltered.lat, dataframefiltered.lng, dataframefiltered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venuesmap)

venuesmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Creating Dataframe for final output
#
# In conclusion, the number of Restaurants in 1km radius from the selected locations were:
#
# - Taj Mahal - 13
# - India Gate - 5
